# %%
import pandas as pd

# %%
df = pd.read_csv("IRIS.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
df = df.replace(to_replace="Iris-setosa", value="1")
df = df.replace(to_replace="Iris-virginica", value="2")
df = df.replace(to_replace="Iris-versicolor", value="3")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 0             5.1          3.5           1.4          0.2       1
# 1             4.9          3.0           1.4          0.2       1
# 2             4.7          3.2           1.3          0.2       1
# 3             4.6          3.1           1.5          0.2       1
# 4             5.0          3.6           1.4          0.2       1
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
count = df.groupby('species').size()['1']
count = df.groupby('species').size()['2']
count = df.groupby('species').size()['3']

# %%
print(f"The number of Setosas is: {count}")
print(f"The number of Verginica is: {count}")
print(f"The number of Versicolor is: {count}")
# Out:
# The number of Setosas is: 50
# The number of Verginica is: 50
# The number of Versicolor is: 50

# %%
count = df['species'].value_counts()['1']

# %%
count
# Out:
# 50

# %%
setosadf=df[df['species'] == '1']

# %%
versidf=df[df['species'] == '3']

# %%
virgindf=df[df['species'] == '2']

# %%
from sklearn.model_selection import train_test_split

# %%
str,stt=train_test_split(setosadf,test_size=0.2)

# %%
vtr,vtt=train_test_split(virgindf,test_size=0.2)

# %%
vertr,vertt=train_test_split(versidf,test_size=0.2)

# %%
train1 = pd.concat([str,vtr], ignore_index=True)

# %%
test1 = pd.concat([stt,vtt], ignore_index=True)

# %%
train = pd.concat([train1,vertr], ignore_index=True)

# %%
test = pd.concat([test1,vertt], ignore_index=True)

# %%
train1
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.8           1.9          0.4       1
# 1            5.1          3.3           1.7          0.5       1
# 2            4.6          3.2           1.4          0.2       1
# 3            4.9          3.1           1.5          0.1       1
# 4            5.0          3.4           1.6          0.4       1
# ..           ...          ...           ...          ...     ...
# 75           5.9          3.0           5.1          1.8       2
# 76           6.3          3.4           5.6          2.4       2
# 77           6.9          3.1           5.1          2.3       2
# 78           5.7          2.5           5.0          2.0       2
# 79           6.3          2.5           5.0          1.9       2
#
# [80 rows x 5 columns]

# %%
train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 0             5.1          3.8           1.9          0.4       1
# 1             5.1          3.3           1.7          0.5       1
# 2             4.6          3.2           1.4          0.2       1
# 3             4.9          3.1           1.5          0.1       1
# 4             5.0          3.4           1.6          0.4       1
# ..            ...          ...           ...          ...     ...
# 115           6.9          3.1           4.9          1.5       3
# 116           5.6          3.0           4.1          1.3       3
# 117           6.0          2.9           4.5          1.5       3
# 118           6.2          2.2           4.5          1.5       3
# 119           5.5          2.3           4.0          1.3       3
#
# [120 rows x 5 columns]

# %%
test
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            4.4          3.2           1.3          0.2       1
# 1            5.8          4.0           1.2          0.2       1
# 2            5.0          3.6           1.4          0.2       1
# 3            5.0          3.2           1.2          0.2       1
# 4            5.5          3.5           1.3          0.2       1
# 5            5.0          3.5           1.3          0.3       1
# 6            4.7          3.2           1.6          0.2       1
# 7            4.8          3.4           1.6          0.2       1
# 8            4.9          3.1           1.5          0.1       1
# 9            4.9          3.0           1.4          0.2       1
# 10           6.1          2.6           5.6          1.4       2
# 11           6.9          3.2           5.7          2.3       2
# 12           7.1          3.0           5.9          2.1       2
# ...

# %%
newdf=pd.concat([setosadf,versidf], ignore_index=True)

# %%
newdf
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2       1
# 1            4.9          3.0           1.4          0.2       1
# 2            4.7          3.2           1.3          0.2       1
# 3            4.6          3.1           1.5          0.2       1
# 4            5.0          3.6           1.4          0.2       1
# ..           ...          ...           ...          ...     ...
# 95           5.7          3.0           4.2          1.2       3
# 96           5.7          2.9           4.2          1.3       3
# 97           6.2          2.9           4.3          1.3       3
# 98           5.1          2.5           3.0          1.1       3
# 99           5.7          2.8           4.1          1.3       3
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import seaborn as sns
sns.scatterplot(data=newdf, x='sepal_length', y='petal_length', hue='species', alpha=1)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>
